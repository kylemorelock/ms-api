# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64, json

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': 'f511afd2d96a44dba7ffd9333d6f2abc',
}

areas = ['computer science']
root_level = []

for area in areas:
    
    params = urllib.parse.urlencode({
    # Request parameters
    "expr": "FN='{}'".format(area),
    'model': 'latest',
    'count': '100',
    'offset': '0',
    'attributes': 'Id,FP.FN,FN,FC.FN,FL,DFN'
    })
        
    try:
        conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
        conn.request("GET", "/academic/v1.0/evaluate?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        with open("data.json", "wb") as f:
            f.write(data)
        print(type(data))
        print(data)
        root_level.append(json.loads(data))
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# <class 'bytes'>
# ...

# %%
import json

level_one_list = []

with open("data.json") as data_file:
    d = json.load(data_file)
    level_zero = d['entities']
    for i in level_zero:
        level_one_json = i['FC']
        try:
            for j in level_one_json:
                level_one = j['FN']
                
                level_one_list.append(level_one)
        except:
            pass
        
print(level_one_list)
# Out:
# ['algorithm', 'programming language', 'computer network', 'mathematical optimization', 'simulation', 'computational science', 'machine learning', 'artificial intelligence', 'real-time computing', 'pattern recognition', 'database', 'data mining', 'computer security', 'distributed computing', 'computer vision', 'bioinformatics', 'operating system', 'information retrieval', 'computer hardware', 'computer architecture', 'speech recognition', 'parallel computing', 'telecommunications', 'world wide web', 'computational biology', 'operations research', 'computer graphics (images)', 'cognitive science', 'multimedia', 'human–computer interaction', 'embedded system', 'knowledge management', 'natural language processing', 'internet privacy', 'theoretical computer science', 'data science', 'management science']

# %%
import time

areas = level_one_list

for area in areas:
    
    time.sleep(3)
    
    params = urllib.parse.urlencode({
    # Request parameters
    "expr": "FN='{}'".format(area),
    'model': 'latest',
    'count': '100',
    'offset': '0',
    'attributes': 'Id,FP.FN,FN,FC.FN,FL,DFN'
    })
        
    try:
        conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
        conn.request("GET", "/academic/v1.0/evaluate?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        with open("data_level_one_{}.json".format(area), "wb") as f:
            f.write(data)
        print(type(data))
        print(data)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# <class 'bytes'>
# b'{\n"expr":"FN=\'algorithm\'",\n"entities":\n[\n{"logprob":-6.961,"Id":11413529,"DFN":"Algorithm","FN":"algorithm","FL":1,"FC":[{"FN":"approximation algorithm"},{"FN":"finite-state machine"},{"FN":"heuristic"},{"FN":"cellular automaton"},{"FN":"abstract machine"},{"FN":"computational number theory"},{"FN":"theory of computation"},{"FN":"algorithm engineering"},{"FN":"axiomatic semantics"}],"FP":[{"FN":"mathematics"},{"FN":"computer science"}]}]\n}\n'
# <class 'bytes'>
# ...

# %%
level_two_list = []

level_one_files_list = []

for area in level_one_list:
    
    file = "data_level_one_{}.json".format(area)
    level_one_files_list.append(file)

for f in level_one_files_list:

    with open(f) as data_file:
        d = json.load(data_file)
        level_one = d['entities']
        try:
            for i in level_one:
                level_two_json = i['FC']
                try:
                    for j in level_two_json:
                        level_two = j['FN']
                
                        level_two_list.append(level_two)
                except:
                    pass
        except:
            pass
        
print(level_two_list)
# Out:
# ['approximation algorithm', 'finite-state machine', 'heuristic', 'cellular automaton', 'abstract machine', 'computational number theory', 'theory of computation', 'algorithm engineering', 'axiomatic semantics', 'data structure', 'concurrent computing', 'finite-state machine', 'functional programming', 'formal methods', 'abstract machine', 'lambda calculus', 'theory of computation', 'software verification', 'axiomatic semantics', 'low-level programming language', 'inductive programming', 'network on a chip', 'network engineering', 'combinatorial optimization', 'linear programming', 'swarm intelligence', 'approximation algorithm', 'nonlinear programming', 'constrained optimization', 'convex optimization', 'quadratic programming', 'global optimization', 'integer programming', 'stochastic optimization', 'job shop scheduling', 'stochastic approximation', 'semidefinite programming', 'vehicle routing problem', 'sequential quadratic programming', 'metaheuristic', 'vector optimization', 'robu
# ...

# %%
areas = level_two_list

for area in areas:
    
    time.sleep(2)
    
    params = urllib.parse.urlencode({
    # Request parameters
    "expr": "FN='{}'".format(area),
    'model': 'latest',
    'count': '100',
    'offset': '0',
    'attributes': 'Id,FP.FN,FN,FC.FN,FL,DFN'
    })
        
    try:
        conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
        conn.request("GET", "/academic/v1.0/evaluate?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        with open("data_level_two_{}.json".format(area), "wb") as f:
            f.write(data)
        print(type(data))
        print(data)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# <class 'bytes'>
# ...

# %%
level_three_list = []

level_two_files_list = []

for area in level_two_list:
    
    file = "data_level_two_{}.json".format(area)
    level_two_files_list.append(file)

for f in level_two_files_list:

    with open(f) as data_file:
        d = json.load(data_file)
        level_two = d['entities']
        try:
            for i in level_two:
                level_three_json = i['FC']
                try:
                    for j in level_three_json:
                        level_three = j['FN']
                
                        level_three_list.append(level_three)
                except:
                    pass
        except:
            pass
        
print(level_three_list)
# Out:
# ['optimization problem', 'computational complexity theory', 'time complexity', 'complete', 'greedy algorithm', 'travelling salesman problem', 'decision problem', 'randomized algorithm', 'np-complete', 'p', 'graph partition', 'np-hard', 'set cover problem', 'cut', 'minimum cut', 'complexity class', 'steiner tree problem', 'nearest neighbour algorithm', 'boolean satisfiability problem', 'randomized rounding', 'pp', 'dominating set', 'polynomial-time approximation scheme', 'multiprocessor scheduling', 'maximum cut', 'hardness of approximation', 'snp', 'linear programming relaxation', 'np', 'conjunctive normal form', 'disjunctive normal form', 'bin packing problem', 'nc', 'longest path problem', 'vertex cover', 'maximal independent set', 'connected dominating set', 'property testing', 'unit disk graph', 'polygon covering', 'subset sum problem', 'up', 'bond graph', 'covering problems', 'maximum satisfiability problem', 'cure data clustering algorithm', 'blossom algorithm', 'color-coding',
# ...

# %%
areas = list(set(level_three_list))

call_count = 0

for area in areas:
    
    time.sleep(2)
    
    params = urllib.parse.urlencode({
    # Request parameters
    "expr": "FN='{}'".format(area),
    'model': 'latest',
    'count': '100',
    'offset': '0',
    'attributes': 'Id,FP.FN,FN,FC.FN,FL,DFN'
    })
        
    try:
        conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
        conn.request("GET", "/academic/v1.0/evaluate?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        
        with open("data_level_three_{}.json".format(area), "wb") as f:
            f.write(data)
        print(area)
        call_count += 1
        print(call_count)
        conn.close()
    except Exception as e:
        print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# definite assignment analysis
# 1
# simplified molecular-input line-entry system
# 2
# rational data type
# 3
# multiprocessing
# 4
# helix bundle
# 5
# drug design
# 6
# security association
# 7
# polymerase chain reaction optimization
# 8
# weighted majority algorithm
# 9
# multicast
# 10
# efficient estimator
# 11
# binary large object
# 12
# sequence read archive
# 13
# biconditional introduction
# 14
# stride of an array
# 15
# grzegorczyk hierarchy
# 16
# refinement
# 17
# ripemd
# 18
# cycl
# 19
# area under the curve
# 20
# dual in-line package
# 21
# capicom
# 22
# retroactive data structures
# 23
# metaproteomics
# 24
# common disease-common variant
# 25
# anscombe transform
# 26
# coons patch
# 27
# rapid update cycle
# 28
# f-statistics
# 29
# financial signal processing
# 30
# bio-inspired computing
# 31
# defensive programming
# 32
# locus
# 33
# physical address
# 34
# [Errno 2] No such file or directory
# sun spot
# 35
# forward algorithm
# 36
# impedance matching
# ...

# %%
print(len(list(set(level_three_list))))

count = 0

for area in list(set(level_three_list)):
    try:
        with open("data_level_three_{}.json".format(area, "r")) as f:
            count += 1
        conn.close()
    except: 
        print("file" + area + "was not found")
print(count)
# Out:
# 9091
# filerdf\/xmlwas not found
# files\/keywas not found
# filemodified condition\/decision coveragewas not found
# fileac\/ac converterwas not found
# fileam\/fm\/giswas not found
# fileaudio time-scale\/pitch modificationwas not found
# fileopen\/closed principlewas not found
# filechannel i\/owas not found
# filelink\/cut treewas not found
# fileid\/lp grammarwas not found
# fileinput\/output completion portwas not found
# filego\/no gowas not found
# filepunched card input\/outputwas not found
# filenon-specific serine\/threonine protein kinasewas not found
# fileapc\/c activator protein cdh1was not found
# filepl\/sqlwas not found
# files\/mimewas not found
# filescaffold\/matrix attachment regionwas not found
# filegnu\/linuxwas not found
# filers\/6000was not found
# filec file input\/outputwas not found
# filea5\/1was not found
# filemaster\/slavewas not found
# filemin\/max kd-treewas not found
# filelocator\/identifier separation protocolwas not found
# ...

# %%
all_parent_areas = ['computer science']

parents_list = [list(set(level_one_list)), list(set(level_two_list)), list(set(level_three_list))]

for i in parents_list:
    all_parent_areas.extend(i)

# %%
import re

alpha_parents = []
non_alpha_parents = []

for area in all_parent_areas:
    for x in area:
        if x.isalpha() or x.isspace():
            alpha_parents.append(area)
        else:
            non_alpha_parents.append(area)
#print(alpha_parents) 
print(non_alpha_parents)
# Out:
# ['computer graphics (images)', 'computer graphics (images)', 'human–computer interaction', 'real-time computing', 'human–robot interaction', 'instance-based learning', 'error-driven learning', 'multi-document summarization', 'computer-automated design', 'hyper-heuristic', 'rule-based system', 'low-level programming language', 'real-time operating system', 'human-based computation', 'competence-based management', 'finite-state machine', 'database-centric architecture', 'computer-assisted translation', 'semi-supervised learning', 'e-commerce', 'multi-agent system', 'knowledge-based systems', 'fiber-optic communication', 'high-frequency trading', 'modula-2', 'modula-2', 'acvr2b', 'traveling-wave tube', 'end-user computing', 'm-tree', 'tf–idf', 'c file input\\/output', 'c file input\\/output', 'time–frequency representation', 'context-based access control', 'phosphodiesterase 3', "kleene's recursion theorem", "aitken's delta-squared process", "aitken's delta-squared process", 'rna-seq', 
# ...

# %%
for area in non_alpha_parents:
    for j in level_two_list:
        if area == j:
            print(area)
# Out:
# human–robot interaction
# instance-based learning
# error-driven learning
# error-driven learning
# multi-document summarization
# multi-document summarization
# computer-automated design
# computer-automated design
# hyper-heuristic
# hyper-heuristic
# rule-based system
# low-level programming language
# real-time operating system
# real-time operating system
# human-based computation
# competence-based management
# finite-state machine
# finite-state machine
# database-centric architecture
# computer-assisted translation
# semi-supervised learning
# e-commerce
# multi-agent system
# knowledge-based systems
# fiber-optic communication
